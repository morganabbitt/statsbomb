# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/events_csvs/events_15946.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                    id  index  period  \
# 0           0  ce508a95-38d3-4248-a50e-dc8d7e23230c      1       1
# 1           1  39abd1c2-2575-41be-ae79-3e936eead529      2       1
# 2           2  1148e967-380f-421f-97f0-d0c820c72984      3       1
# 3           3  7cf6876d-7c50-4d64-b999-e2a039641c81      4       1
# 4           4  34208ade-2af4-45c3-970e-655937cad938      5       1
#
#       timestamp  minute  second  possession  duration  type.id    type.name  \
# 0  00:00:00.000       0       0           1     0.000       35  Starting XI
# 1  00:00:00.000       0       0           1     0.000       35  Starting XI
# 2  00:00:00.000       0       0           1     0.000       18   Half Start
# 3  00:00:00.000       0       0           1     0.000       18   Half Start
# 4  00:00:00.098       0       0           2     1.909       30         Pass
#
#    possession_team.id possession_team.name  play_pattern.id play_pattern.name  \
# ...

# %%
df.iloc[:10, :20].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            10 non-null     int64
#  1   id                    10 non-null     object
#  2   index                 10 non-null     int64
#  3   period                10 non-null     int64
#  4   timestamp             10 non-null     object
#  5   minute                10 non-null     int64
#  6   second                10 non-null     int64
#  7   possession            10 non-null     int64
#  8   duration              8 non-null      float64
#  9   type.id               10 non-null     int64
#  10  type.name             10 non-null     object
#  11  possession_team.id    10 non-null     int64
#  12  possession_team.name  10 non-null     object
#  13  play_pattern.id       10 non-null     int64
#  14  play_pattern.name     10 non-null     object
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'id', 'index', 'period', 'timestamp', 'minute',
#        'second', 'possession', 'duration', 'type.id', 'type.name',
#        'possession_team.id', 'possession_team.name', 'play_pattern.id',
#        'play_pattern.name', 'team.id', 'team.name', 'tactics.formation',
#        'tactics.lineup', 'related_events', 'location', 'player.id',
#        'player.name', 'position.id', 'position.name', 'pass.recipient.id',
#        'pass.recipient.name', 'pass.length', 'pass.angle',
#        'pass.height.id', 'pass.height.name', 'pass.end_location',
#        'pass.body_part.id', 'pass.body_part.name', 'pass.type.id',
#        'pass.type.name', 'carry.end_location', 'pass.switch',
#        'pass.outcome.id', 'pass.outcome.name', 'ball_receipt.outcome.id',
#        'ball_receipt.outcome.name', 'counterpress', 'under_pressure',
#        'ball_recovery.recovery_failure', 'pass.assisted_shot_id',
#        'pass.shot_assist', 'pass.through_ball', 'pass.technique.id',
# ...
